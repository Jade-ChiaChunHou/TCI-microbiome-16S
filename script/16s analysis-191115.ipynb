# %% [markdown]
# ### Part 0: Import and Download NCBI Taxa Database
#
# reference:http://etetoolkit.org/docs/latest/tutorial/tutorial_ncbitaxonomy.html

# %%
import numpy as np
import pandas as pd
from ete3 import NCBITaxa

# %%
# Download NCBI Taxa Database
ncbi = NCBITaxa()
#ncbi.update_taxonomy_database()

# %% [markdown]
# ### Part 1: Read Nanopore Data

# %%
file_path = '../data/191115/12_gut_test_classification.csv'
result_path = '../result/191115/'

raw = pd.read_csv('../data/191115/12_gut_test_classification.csv', encoding = 'utf-8')

############################
# how many diferrent barcode

raw['barcode'].unique()
# Out:
# array(['BC01', 'BC10', 'BC12', 'BC02', 'BC11', 'BC08', 'BC06', 'BC04',
#        'BC09', 'BC05', 'BC07', 'BC03', nan], dtype=object)

# %%
raw.head()
# Out:
#                                             filename  \
# 0  fastq_runid_0d12eab41107590678909ab4b985f43e38...
# 1  fastq_runid_0d12eab41107590678909ab4b985f43e38...
# 2  fastq_runid_0d12eab41107590678909ab4b985f43e38...
# 3  fastq_runid_0d12eab41107590678909ab4b985f43e38...
# 4  fastq_runid_0d12eab41107590678909ab4b985f43e38...
#
#                                 read_id                exit_status  \
# 0  00cd5abd-7e2e-4327-8c30-ffbf7f38e0bf  Classification successful
# 1  011a6dd8-ac78-4aea-8876-77a11002d63d  Classification successful
# 2  0268997c-6c0f-4c29-85e0-7876956c1518  Classification successful
# 3  02d1af6d-3a03-4b76-a3af-d9106058d522  Classification successful
# 4  030f2253-419c-4bb7-8d5d-998ddabbe851  Classification successful
#
#                                       runid    taxid barcode  accuracy  lca  \
# 0  0d12eab41107590678909ab4b985f43e389bdb15   186802    BC01     77.55    1
# 1  0d12eab41107590678909ab4b985f43e389bdb15   541000    BC10     87.34    1
# 2  0d12eab41107590678909ab4b985f43e389bdb15   186803    BC10     94.40    1
# 3  0d12eab41107590678909ab4b985f43e389bdb15   186802    BC01     86.73    1
# 4  0d12eab41107590678909ab4b985f43e389bdb15  1411144    BC12     85.47    0
#
#    genus_taxid
# 0           -1
# 1           -1
# 2           -1
# 3           -1
# 4          816

# %%
#################################################
# Select raw data 
# (1) 'exit_status' == 'Classification successful'
# (2) 'barcode' == BC01, BC02, BC03, BC04

raw = pd.read_csv(file_path, encoding = 'utf-8')


#####
#BC01
#####
raw_sucess_BC01 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC01')]

raw_sucess_BC01.to_csv(result_path +'raw_sucess_BC01.csv', encoding='utf-8')
print('BC01 read count:', len(raw_sucess_BC01))


#####
#BC02
#####
raw_sucess_BC02 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC02')]

raw_sucess_BC02.to_csv(result_path +'raw_sucess_BC02.csv', encoding='utf-8')
print('BC02 read count:',len(raw_sucess_BC02))


#####
#BC03
#####
raw_sucess_BC03 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC03')]

raw_sucess_BC03.to_csv(result_path +'raw_sucess_BC03.csv', encoding='utf-8')
print('BC03 read count:',len(raw_sucess_BC03))



#####
#BC04
#####
raw_sucess_BC04 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC04')]

raw_sucess_BC04.to_csv(result_path +'raw_sucess_BC04.csv', encoding='utf-8')
print('BC04 read count:',len(raw_sucess_BC04))



#####
#BC05
#####
raw_sucess_BC05 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC05')]

raw_sucess_BC05.to_csv(result_path +'raw_sucess_BC05.csv', encoding='utf-8')
print('BC05 read count:',len(raw_sucess_BC05))



#####
#BC06
#####
raw_sucess_BC06 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC06')]

raw_sucess_BC06.to_csv(result_path +'raw_sucess_BC06.csv', encoding='utf-8')
print('BC06 read count:',len(raw_sucess_BC06))



#####
#BC07
#####
raw_sucess_BC07 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC07')]

raw_sucess_BC07.to_csv(result_path +'raw_sucess_BC07.csv', encoding='utf-8')
print('BC07 read count:',len(raw_sucess_BC07))



#####
#BC08
#####
raw_sucess_BC08 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC08')]

raw_sucess_BC08.to_csv(result_path +'raw_sucess_BC08.csv', encoding='utf-8')
print('BC08 read count:',len(raw_sucess_BC08))



#####
#BC09
#####
raw_sucess_BC09 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC09')]

raw_sucess_BC09.to_csv(result_path +'raw_sucess_BC09.csv', encoding='utf-8')
print('BC09 read count:',len(raw_sucess_BC09))



#####
#BC10
#####
raw_sucess_BC10 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC10')]

raw_sucess_BC10.to_csv(result_path +'raw_sucess_BC10.csv', encoding='utf-8')
print('BC10 read count:',len(raw_sucess_BC10))



#####
#BC11
#####
raw_sucess_BC11 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC11')]

raw_sucess_BC11.to_csv(result_path +'raw_sucess_BC11.csv', encoding='utf-8')
print('BC11 read count:',len(raw_sucess_BC11))



#####
#BC12
#####
raw_sucess_BC12 = raw[(raw['exit_status'] == 'Classification successful') & (raw['barcode'] == 'BC12')]

raw_sucess_BC12.to_csv(result_path +'raw_sucess_BC12.csv', encoding='utf-8')
print('BC12 read count:',len(raw_sucess_BC12))
# Out:
# BC01 read count: 90502
# BC02 read count: 96384
# BC03 read count: 13559
# BC04 read count: 65033
# BC05 read count: 114032
# BC06 read count: 111664
# BC07 read count: 27294
# BC08 read count: 79342
# BC09 read count: 81997
# BC10 read count: 80869
# BC11 read count: 114584
# BC12 read count: 147803

# %%
# BC01 accurate rate

BC01_total = len(raw_sucess_BC01)

BC01_99 = len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 99)])
BC01_95 = len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 95)])
BC01_90 = len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 90)])
BC01_85 = len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 85)])
BC01_80 = len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 80)])
BC01_75 = len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 75)])

BC01_99_per = (len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 99)]) / len(raw_sucess_BC01)) * 100
BC01_95_per = (len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 95)]) / len(raw_sucess_BC01)) * 100
BC01_90_per = (len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 90)]) / len(raw_sucess_BC01)) * 100
BC01_85_per = (len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 85)]) / len(raw_sucess_BC01)) * 100
BC01_80_per = (len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 80)]) / len(raw_sucess_BC01)) * 100
BC01_75_per = (len(raw_sucess_BC01[(raw_sucess_BC01['accuracy'] > 75)]) / len(raw_sucess_BC01)) * 100


# BC02 accurate rate

BC02_total = len(raw_sucess_BC02)

BC02_99 = len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 99)])
BC02_95 = len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 95)])
BC02_90 = len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 90)])
BC02_85 = len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 85)])
BC02_80 = len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 80)])
BC02_75 = len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 75)])

BC02_99_per = (len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 99)]) / len(raw_sucess_BC02)) * 100
BC02_95_per = (len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 95)]) / len(raw_sucess_BC02)) * 100
BC02_90_per = (len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 90)]) / len(raw_sucess_BC02)) * 100
BC02_85_per = (len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 85)]) / len(raw_sucess_BC02)) * 100
BC02_80_per = (len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 80)]) / len(raw_sucess_BC02)) * 100
BC02_75_per = (len(raw_sucess_BC02[(raw_sucess_BC02['accuracy'] > 75)]) / len(raw_sucess_BC02)) * 100


# BC03 accurate rate

BC03_total = len(raw_sucess_BC03)

BC03_99 = len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 99)])
BC03_95 = len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 95)])
BC03_90 = len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 90)])
BC03_85 = len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 85)])
BC03_80 = len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 80)])
BC03_75 = len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 75)])

BC03_99_per = (len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 99)]) / len(raw_sucess_BC03)) * 100
BC03_95_per = (len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 95)]) / len(raw_sucess_BC03)) * 100
BC03_90_per = (len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 90)]) / len(raw_sucess_BC03)) * 100
BC03_85_per = (len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 85)]) / len(raw_sucess_BC03)) * 100
BC03_80_per = (len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 80)]) / len(raw_sucess_BC03)) * 100
BC03_75_per = (len(raw_sucess_BC03[(raw_sucess_BC03['accuracy'] > 75)]) / len(raw_sucess_BC03)) * 100


# BC04 accurate rate

BC04_total = len(raw_sucess_BC04)

BC04_99 = len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 99)])
BC04_95 = len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 95)])
BC04_90 = len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 90)])
BC04_85 = len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 85)])
BC04_80 = len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 80)])
BC04_75 = len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 75)])

BC04_99_per = (len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 99)]) / len(raw_sucess_BC04)) * 100
BC04_95_per = (len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 95)]) / len(raw_sucess_BC04)) * 100
BC04_90_per = (len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 90)]) / len(raw_sucess_BC04)) * 100
BC04_85_per = (len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 85)]) / len(raw_sucess_BC04)) * 100
BC04_80_per = (len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 80)]) / len(raw_sucess_BC04)) * 100
BC04_75_per = (len(raw_sucess_BC04[(raw_sucess_BC04['accuracy'] > 75)]) / len(raw_sucess_BC04)) * 100


# BC05 accurate rate

BC05_total = len(raw_sucess_BC05)

BC05_99 = len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 99)])
BC05_95 = len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 95)])
BC05_90 = len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 90)])
BC05_85 = len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 85)])
BC05_80 = len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 80)])
BC05_75 = len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 75)])

BC05_99_per = (len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 99)]) / len(raw_sucess_BC05)) * 100
BC05_95_per = (len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 95)]) / len(raw_sucess_BC05)) * 100
BC05_90_per = (len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 90)]) / len(raw_sucess_BC05)) * 100
BC05_85_per = (len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 85)]) / len(raw_sucess_BC05)) * 100
BC05_80_per = (len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 80)]) / len(raw_sucess_BC05)) * 100
BC05_75_per = (len(raw_sucess_BC05[(raw_sucess_BC05['accuracy'] > 75)]) / len(raw_sucess_BC05)) * 100



# BC06 accurate rate

BC06_total = len(raw_sucess_BC06)

BC06_99 = len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 99)])
BC06_95 = len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 95)])
BC06_90 = len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 90)])
BC06_85 = len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 85)])
BC06_80 = len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 80)])
BC06_75 = len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 75)])

BC06_99_per = (len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 99)]) / len(raw_sucess_BC06)) * 100
BC06_95_per = (len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 95)]) / len(raw_sucess_BC06)) * 100
BC06_90_per = (len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 90)]) / len(raw_sucess_BC06)) * 100
BC06_85_per = (len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 85)]) / len(raw_sucess_BC06)) * 100
BC06_80_per = (len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 80)]) / len(raw_sucess_BC06)) * 100
BC06_75_per = (len(raw_sucess_BC06[(raw_sucess_BC06['accuracy'] > 75)]) / len(raw_sucess_BC06)) * 100


# BC07 accurate rate

BC07_total = len(raw_sucess_BC07)

BC07_99 = len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 99)])
BC07_95 = len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 95)])
BC07_90 = len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 90)])
BC07_85 = len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 85)])
BC07_80 = len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 80)])
BC07_75 = len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 75)])

BC07_99_per = (len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 99)]) / len(raw_sucess_BC07)) * 100
BC07_95_per = (len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 95)]) / len(raw_sucess_BC07)) * 100
BC07_90_per = (len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 90)]) / len(raw_sucess_BC07)) * 100
BC07_85_per = (len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 85)]) / len(raw_sucess_BC07)) * 100
BC07_80_per = (len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 80)]) / len(raw_sucess_BC07)) * 100
BC07_75_per = (len(raw_sucess_BC07[(raw_sucess_BC07['accuracy'] > 75)]) / len(raw_sucess_BC07)) * 100


# BC08 accurate rate

BC08_total = len(raw_sucess_BC08)

BC08_99 = len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 99)])
BC08_95 = len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 95)])
BC08_90 = len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 90)])
BC08_85 = len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 85)])
BC08_80 = len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 80)])
BC08_75 = len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 75)])

BC08_99_per = (len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 99)]) / len(raw_sucess_BC08)) * 100
BC08_95_per = (len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 95)]) / len(raw_sucess_BC08)) * 100
BC08_90_per = (len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 90)]) / len(raw_sucess_BC08)) * 100
BC08_85_per = (len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 85)]) / len(raw_sucess_BC08)) * 100
BC08_80_per = (len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 80)]) / len(raw_sucess_BC08)) * 100
BC08_75_per = (len(raw_sucess_BC08[(raw_sucess_BC08['accuracy'] > 75)]) / len(raw_sucess_BC08)) * 100


# BC09 accurate rate

BC09_total = len(raw_sucess_BC09)

BC09_99 = len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 99)])
BC09_95 = len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 95)])
BC09_90 = len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 90)])
BC09_85 = len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 85)])
BC09_80 = len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 80)])
BC09_75 = len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 75)])

BC09_99_per = (len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 99)]) / len(raw_sucess_BC09)) * 100
BC09_95_per = (len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 95)]) / len(raw_sucess_BC09)) * 100
BC09_90_per = (len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 90)]) / len(raw_sucess_BC09)) * 100
BC09_85_per = (len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 85)]) / len(raw_sucess_BC09)) * 100
BC09_80_per = (len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 80)]) / len(raw_sucess_BC09)) * 100
BC09_75_per = (len(raw_sucess_BC09[(raw_sucess_BC09['accuracy'] > 75)]) / len(raw_sucess_BC09)) * 100


# BC10 accurate rate

BC10_total = len(raw_sucess_BC10)

BC10_99 = len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 99)])
BC10_95 = len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 95)])
BC10_90 = len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 90)])
BC10_85 = len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 85)])
BC10_80 = len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 80)])
BC10_75 = len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 75)])

BC10_99_per = (len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 99)]) / len(raw_sucess_BC10)) * 100
BC10_95_per = (len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 95)]) / len(raw_sucess_BC10)) * 100
BC10_90_per = (len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 90)]) / len(raw_sucess_BC10)) * 100
BC10_85_per = (len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 85)]) / len(raw_sucess_BC10)) * 100
BC10_80_per = (len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 80)]) / len(raw_sucess_BC10)) * 100
BC10_75_per = (len(raw_sucess_BC10[(raw_sucess_BC10['accuracy'] > 75)]) / len(raw_sucess_BC10)) * 100


# BC11 accurate rate

BC11_total = len(raw_sucess_BC11)

BC11_99 = len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 99)])
BC11_95 = len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 95)])
BC11_90 = len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 90)])
BC11_85 = len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 85)])
BC11_80 = len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 80)])
BC11_75 = len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 75)])

BC11_99_per = (len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 99)]) / len(raw_sucess_BC11)) * 100
BC11_95_per = (len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 95)]) / len(raw_sucess_BC11)) * 100
BC11_90_per = (len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 90)]) / len(raw_sucess_BC11)) * 100
BC11_85_per = (len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 85)]) / len(raw_sucess_BC11)) * 100
BC11_80_per = (len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 80)]) / len(raw_sucess_BC11)) * 100
BC11_75_per = (len(raw_sucess_BC11[(raw_sucess_BC11['accuracy'] > 75)]) / len(raw_sucess_BC11)) * 100


# BC12 accurate rate

BC12_total = len(raw_sucess_BC12)

BC12_99 = len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 99)])
BC12_95 = len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 95)])
BC12_90 = len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 90)])
BC12_85 = len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 85)])
BC12_80 = len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 80)])
BC12_75 = len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 75)])

BC12_99_per = (len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 99)]) / len(raw_sucess_BC12)) * 100
BC12_95_per = (len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 95)]) / len(raw_sucess_BC12)) * 100
BC12_90_per = (len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 90)]) / len(raw_sucess_BC12)) * 100
BC12_85_per = (len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 85)]) / len(raw_sucess_BC12)) * 100
BC12_80_per = (len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 80)]) / len(raw_sucess_BC12)) * 100
BC12_75_per = (len(raw_sucess_BC12[(raw_sucess_BC12['accuracy'] > 75)]) / len(raw_sucess_BC12)) * 100

print('finish')
# Out:
# finish

# %%
data = {'BC01':[BC01_total, BC01_99, BC01_95, BC01_90, BC01_85, BC01_80, BC01_75, BC01_99_per, BC01_95_per, BC01_90_per, BC01_85_per, BC01_80_per, BC01_75_per],
        'BC02':[BC02_total, BC02_99, BC02_95, BC02_90, BC02_85, BC02_80, BC02_75, BC02_99_per, BC02_95_per, BC02_90_per, BC02_85_per, BC02_80_per, BC02_75_per],
        'BC03':[BC03_total, BC03_99, BC03_95, BC03_90, BC03_85, BC03_80, BC03_75, BC03_99_per, BC03_95_per, BC03_90_per, BC03_85_per, BC03_80_per, BC03_75_per],
        'BC04':[BC04_total, BC04_99, BC04_95, BC04_90, BC04_85, BC04_80, BC04_75, BC04_99_per, BC04_95_per, BC04_90_per, BC04_85_per, BC04_80_per, BC04_75_per],
        'BC05':[BC05_total, BC05_99, BC05_95, BC05_90, BC05_85, BC05_80, BC05_75, BC05_99_per, BC05_95_per, BC05_90_per, BC05_85_per, BC05_80_per, BC05_75_per],
        'BC06':[BC06_total, BC06_99, BC06_95, BC06_90, BC06_85, BC06_80, BC06_75, BC06_99_per, BC06_95_per, BC06_90_per, BC06_85_per, BC06_80_per, BC06_75_per],
        'BC07':[BC07_total, BC07_99, BC07_95, BC07_90, BC07_85, BC07_80, BC07_75, BC07_99_per, BC07_95_per, BC07_90_per, BC07_85_per, BC07_80_per, BC07_75_per],
        'BC08':[BC08_total, BC08_99, BC08_95, BC08_90, BC08_85, BC08_80, BC08_75, BC08_99_per, BC08_95_per, BC08_90_per, BC08_85_per, BC08_80_per, BC08_75_per],
        'BC09':[BC09_total, BC09_99, BC09_95, BC09_90, BC09_85, BC09_80, BC09_75, BC09_99_per, BC09_95_per, BC09_90_per, BC09_85_per, BC09_80_per, BC09_75_per],
        'BC10':[BC10_total, BC10_99, BC10_95, BC10_90, BC10_85, BC10_80, BC10_75, BC10_99_per, BC10_95_per, BC10_90_per, BC10_85_per, BC10_80_per, BC10_75_per],
        'BC11':[BC11_total, BC11_99, BC11_95, BC11_90, BC11_85, BC11_80, BC11_75, BC11_99_per, BC11_95_per, BC11_90_per, BC11_85_per, BC11_80_per, BC11_75_per],
        'BC12':[BC12_total, BC12_99, BC12_95, BC12_90, BC12_85, BC12_80, BC12_75, BC12_99_per, BC12_95_per, BC12_90_per, BC12_85_per, BC12_80_per, BC12_75_per]
       }


accurate_rate = pd.DataFrame(data, index = ['Barcode total count', 'above 99%', 'above 95%', 'above 90%', 'above 85%', 'above 80%', 'above75%', 
                                            'above 99% percentage', 'above 95% percentage', 'above 90% percentage', 'above 85% percentage', 'above 80% percentage', 'above75% percentage'])

#print('BC01 total count: ', len(raw_sucess_BC01))
#rint(BC01_99, BC01_95, BC01_90, BC01_85, BC01_80, BC01_75)
#rint(BC01_99_per, BC01_95_per, BC01_90_per, BC01_85_per, BC01_80_per, BC01_75_per)

accurate_rate.to_csv(result_path +'accurate_rate_barcode_1_12.csv', encoding='utf-8')
accurate_rate
# Out:
#                               BC01          BC02          BC03          BC04  \
# Barcode total count   90502.000000  96384.000000  13559.000000  65033.000000
# above 99%                24.000000     45.000000      2.000000     11.000000
# above 95%              1718.000000   4440.000000    928.000000   5883.000000
# above 90%             16864.000000  41468.000000   8877.000000  45244.000000
# above 85%             47749.000000  77543.000000  12889.000000  63269.000000
# above 80%             85000.000000  94571.000000  13539.000000  65006.000000
# above75%              90502.000000  96384.000000  13559.000000  65033.000000
# above 99% percentage      0.026519      0.046688      0.014750      0.016914
# above 95% percentage      1.898301      4.606574      6.844163      9.046177
# above 90% percentage     18.633842     43.023738     65.469430     69.570833
# above 85% percentage     52.760160     80.452150     95.058633     97.287531
# above 80% percentage     93.920576     98.118982     99.852496     99.958483
# above75% percentage     100.000000    100.000000    100.000000    100.000000
#
#                                BC05           BC06          BC07  \
# Barcode total count   114032.000000  111664.000000  27294.000000
# above 99%                 43.000000      38.000000      3.000000
# above 95%               8753.000000   10176.000000   3741.000000
# above 90%              77960.000000   84891.000000  23296.000000
# above 85%             108956.000000  109151.000000  27082.000000
# above 80%             113919.000000  111614.000000  27288.000000
# above75%              114032.000000  111664.000000  27294.000000
# above 99% percentage       0.037709       0.034031      0.010991
# above 95% percentage       7.675916       9.113053     13.706309
# above 90% percentage      68.366774      76.023607     85.352092
# above 85% percentage      95.548618      97.749498     99.223273
# above 80% percentage      99.900905      99.955223     99.978017
# above75% percentage      100.000000     100.000000    100.000000
#
#                               BC08          BC09          BC10           BC11  \
# Barcode total count   79342.000000  81997.000000  80869.000000  114584.000000
# above 99%                23.000000     20.000000     14.000000      34.000000
# above 95%              3952.000000   8188.000000   3082.000000    5621.000000
# above 90%             44279.000000  63750.000000  41275.000000   77759.000000
# above 85%             71831.000000  80615.000000  72510.000000  109331.000000
# above 80%             79022.000000  81968.000000  80494.000000  114442.000000
# above75%              79342.000000  81997.000000  80869.000000  114584.000000
# above 99% percentage      0.028988      0.024391      0.017312       0.029673
# above 95% percentage      4.980968      9.985731      3.811102       4.905571
# above 90% percentage     55.807769     77.746747     51.039335      67.862005
# above 85% percentage     90.533387     98.314572     89.663530      95.415590
# above 80% percentage     99.596683     99.964633     99.536287      99.876073
# above75% percentage     100.000000    100.000000    100.000000     100.000000
#
#                                BC12
# Barcode total count   147803.000000
# above 99%                 29.000000
# above 95%               5051.000000
# above 90%              65003.000000
# above 85%             121973.000000
# above 80%             144912.000000
# above75%              147803.000000
# above 99% percentage       0.019621
# above 95% percentage       3.417387
# above 90% percentage      43.979486
# above 85% percentage      82.524035
# above 80% percentage      98.044018
# above75% percentage      100.000000

# %%
#####################
# BC01 groupby taxid

taxid_list_bc01 = pd.DataFrame(raw_sucess_BC01.groupby('taxid').count()['read_id'])

taxid_list_bc01.columns = ['read_count']

taxid_list_bc01.to_csv(result_path + 'taxid_list_bc01.csv', encoding='utf-8')
taxid_list_bc01.head()



#####################
# BC02 groupby taxid

taxid_list_bc02 = pd.DataFrame(raw_sucess_BC02.groupby('taxid').count()['read_id'])

taxid_list_bc02.columns = ['read_count']

taxid_list_bc02.to_csv(result_path + 'taxid_list_bc02.csv', encoding='utf-8')
taxid_list_bc02.head()


#####################
# BC03 groupby taxid

taxid_list_bc03 = pd.DataFrame(raw_sucess_BC03.groupby('taxid').count()['read_id'])

taxid_list_bc03.columns = ['read_count']

taxid_list_bc03.to_csv(result_path + 'taxid_list_bc03.csv', encoding='utf-8')
taxid_list_bc03.head()



#####################
# BC04 groupby taxid

taxid_list_bc04 = pd.DataFrame(raw_sucess_BC04.groupby('taxid').count()['read_id'])

taxid_list_bc04.columns = ['read_count']

taxid_list_bc04.to_csv(result_path + 'taxid_list_bc04.csv', encoding='utf-8')
taxid_list_bc04.head()



#####################
# BC05 groupby taxid

taxid_list_bc05 = pd.DataFrame(raw_sucess_BC05.groupby('taxid').count()['read_id'])

taxid_list_bc05.columns = ['read_count']

taxid_list_bc05.to_csv(result_path + 'taxid_list_bc05.csv', encoding='utf-8')
taxid_list_bc05.head()




#####################
# BC06 groupby taxid

taxid_list_bc06 = pd.DataFrame(raw_sucess_BC06.groupby('taxid').count()['read_id'])

taxid_list_bc06.columns = ['read_count']

taxid_list_bc06.to_csv(result_path + 'taxid_list_bc06.csv', encoding='utf-8')
taxid_list_bc06.head()



#####################
# BC07 groupby taxid

taxid_list_bc07 = pd.DataFrame(raw_sucess_BC07.groupby('taxid').count()['read_id'])

taxid_list_bc07.columns = ['read_count']

taxid_list_bc07.to_csv(result_path + 'taxid_list_bc07.csv', encoding='utf-8')
taxid_list_bc07.head()



#####################
# BC08 groupby taxid

taxid_list_bc08 = pd.DataFrame(raw_sucess_BC08.groupby('taxid').count()['read_id'])

taxid_list_bc08.columns = ['read_count']

taxid_list_bc08.to_csv(result_path + 'taxid_list_bc08.csv', encoding='utf-8')
taxid_list_bc08.head()



#####################
# BC09 groupby taxid

taxid_list_bc09 = pd.DataFrame(raw_sucess_BC09.groupby('taxid').count()['read_id'])

taxid_list_bc09.columns = ['read_count']

taxid_list_bc09.to_csv(result_path + 'taxid_list_bc09.csv', encoding='utf-8')
taxid_list_bc09.head()



#####################
# BC10 groupby taxid

taxid_list_bc10 = pd.DataFrame(raw_sucess_BC10.groupby('taxid').count()['read_id'])

taxid_list_bc10.columns = ['read_count']

taxid_list_bc10.to_csv(result_path + 'taxid_list_bc10.csv', encoding='utf-8')
taxid_list_bc10.head()



#####################
# BC11 groupby taxid

taxid_list_bc11 = pd.DataFrame(raw_sucess_BC11.groupby('taxid').count()['read_id'])

taxid_list_bc11.columns = ['read_count']

taxid_list_bc11.to_csv(result_path + 'taxid_list_bc11.csv', encoding='utf-8')
taxid_list_bc11.head()



#####################
# BC12 groupby taxid

taxid_list_bc12 = pd.DataFrame(raw_sucess_BC12.groupby('taxid').count()['read_id'])

taxid_list_bc12.columns = ['read_count']

taxid_list_bc12.to_csv(result_path + 'taxid_list_bc12.csv', encoding='utf-8')
taxid_list_bc12.head()
# Out:
#        read_count
# taxid
# 2            3436
# 29              1
# 39              1
# 54             10
# 356            26

# %% [markdown]
# ### Part 2: Analysis 16s

# %% [markdown]
# ### No Selection in accuracy

# %%
##############
# BC01 lineage
##############

############
# get taxid 

taxid01 = list(taxid_list_bc01.index)
read_count01 = list(taxid_list_bc01['read_count'])
total_count01 = len(raw_sucess_BC01)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage01 = pd.DataFrame(columns= ['taxid'])
id_lineage01['taxid'] = taxid01
id_lineage01.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid01)):
    L = ncbi.get_lineage(taxid01[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage01.at[i, list(rank.values())[0]] = str(node)
        

id_lineage01.head()
      
    
    
##############
# BC02 lineage
##############

############
# get taxid 

taxid02 = list(taxid_list_bc02.index)
read_count02 = list(taxid_list_bc02['read_count'])
total_count02 = len(raw_sucess_BC02)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage02 = pd.DataFrame(columns= ['taxid'])
id_lineage02['taxid'] = taxid02
id_lineage02.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid02)):
    L = ncbi.get_lineage(taxid02[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage02.at[i, list(rank.values())[0]] = str(node)
        

id_lineage02.head()




##############
# BC03 lineage
##############

############
# get taxid 

taxid03 = list(taxid_list_bc03.index)
read_count03 = list(taxid_list_bc03['read_count'])
total_count03 = len(raw_sucess_BC03)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage03 = pd.DataFrame(columns= ['taxid'])
id_lineage03['taxid'] = taxid03
id_lineage03.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid03)):
    L = ncbi.get_lineage(taxid03[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage03.at[i, list(rank.values())[0]] = str(node)
        

id_lineage03.head()



##############
# BC04 lineage
##############

############
# get taxid 

taxid04 = list(taxid_list_bc04.index)
read_count04 = list(taxid_list_bc04['read_count'])
total_count04 = len(raw_sucess_BC04)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage04 = pd.DataFrame(columns= ['taxid'])
id_lineage04['taxid'] = taxid04
id_lineage04.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid04)):
    L = ncbi.get_lineage(taxid04[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage04.at[i, list(rank.values())[0]] = str(node)
        

id_lineage04.head()




##############
# BC05 lineage
##############

############
# get taxid 

taxid05 = list(taxid_list_bc05.index)
read_count05 = list(taxid_list_bc05['read_count'])
total_count05 = len(raw_sucess_BC05)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage05 = pd.DataFrame(columns= ['taxid'])
id_lineage05['taxid'] = taxid05
id_lineage05.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid05)):
    L = ncbi.get_lineage(taxid05[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage05.at[i, list(rank.values())[0]] = str(node)
        

id_lineage05.head()



##############
# BC06 lineage
##############

############
# get taxid 

taxid06 = list(taxid_list_bc06.index)
read_count06 = list(taxid_list_bc06['read_count'])
total_count06 = len(raw_sucess_BC06)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage06 = pd.DataFrame(columns= ['taxid'])
id_lineage06['taxid'] = taxid06
id_lineage06.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid06)):
    L = ncbi.get_lineage(taxid06[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage06.at[i, list(rank.values())[0]] = str(node)
        

id_lineage06.head()




##############
# BC07 lineage
##############

############
# get taxid 

taxid07 = list(taxid_list_bc07.index)
read_count07 = list(taxid_list_bc07['read_count'])
total_count07 = len(raw_sucess_BC07)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage07 = pd.DataFrame(columns= ['taxid'])
id_lineage07['taxid'] = taxid07
id_lineage07.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid07)):
    L = ncbi.get_lineage(taxid07[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage07.at[i, list(rank.values())[0]] = str(node)
        

id_lineage07.head()
      
    
    
##############
# BC08 lineage
##############

############
# get taxid 

taxid08 = list(taxid_list_bc08.index)
read_count08 = list(taxid_list_bc08['read_count'])
total_count08 = len(raw_sucess_BC08)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage08 = pd.DataFrame(columns= ['taxid'])
id_lineage08['taxid'] = taxid08
id_lineage08.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid08)):
    L = ncbi.get_lineage(taxid08[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage08.at[i, list(rank.values())[0]] = str(node)
        

id_lineage08.head()




##############
# BC09 lineage
##############

############
# get taxid 

taxid09 = list(taxid_list_bc09.index)
read_count09 = list(taxid_list_bc09['read_count'])
total_count09 = len(raw_sucess_BC09)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage09 = pd.DataFrame(columns= ['taxid'])
id_lineage09['taxid'] = taxid09
id_lineage09.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid09)):
    L = ncbi.get_lineage(taxid09[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage09.at[i, list(rank.values())[0]] = str(node)
        

id_lineage09.head()



##############
# BC10 lineage
##############

############
# get taxid 

taxid10 = list(taxid_list_bc10.index)
read_count10 = list(taxid_list_bc10['read_count'])
total_count10 = len(raw_sucess_BC10)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage10 = pd.DataFrame(columns= ['taxid'])
id_lineage10['taxid'] = taxid10
id_lineage10.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid10)):
    L = ncbi.get_lineage(taxid10[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage10.at[i, list(rank.values())[0]] = str(node)
        

id_lineage10.head()




##############
# BC11 lineage
##############

############
# get taxid 

taxid11 = list(taxid_list_bc11.index)
read_count11 = list(taxid_list_bc11['read_count'])
total_count11 = len(raw_sucess_BC11)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage11 = pd.DataFrame(columns= ['taxid'])
id_lineage11['taxid'] = taxid11
id_lineage11.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid11)):
    L = ncbi.get_lineage(taxid11[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage11.at[i, list(rank.values())[0]] = str(node)
        

id_lineage11.head()



##############
# BC12 lineage
##############

############
# get taxid 

taxid12 = list(taxid_list_bc12.index)
read_count12 = list(taxid_list_bc12['read_count'])
total_count12 = len(raw_sucess_BC12)


##########################################################
# Create id_lineage dataframe to match the id with lineage

id_lineage12 = pd.DataFrame(columns= ['taxid'])
id_lineage12['taxid'] = taxid12
id_lineage12.head()

###############################################
# the lineage of id add to id_lineage dataframe

for i in range(len(taxid12)):
    L = ncbi.get_lineage(taxid12[i])
    
    for node in L:
        
        rank = ncbi.get_rank([node])
        id_lineage12.at[i, list(rank.values())[0]] = str(node)
        

id_lineage12.head()
# Out:
# /home/tcigene/anaconda3/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:240: UserWarning: taxid 1432309 was translated into 1335613
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
#    taxid no rank superkingdom phylum subphylum  class order suborder  family  \
# 0      2  131567            2    NaN       NaN    NaN   NaN      NaN     NaN
# 1     29  131567            2   1224     68525  28221    29      NaN     NaN
# 2     39  131567            2   1224     68525  28221    29    80811      39
# 3     54  131567            2   1224     68525  28221    29   224462  224463
# 4    356  131567            2   1224       NaN  28211   356      NaN     NaN
#
#   genus species species group subspecies subclass
# 0   NaN     NaN           NaN        NaN      NaN
# 1   NaN     NaN           NaN        NaN      NaN
# 2   NaN     NaN           NaN        NaN      NaN
# 3    53      54           NaN        NaN      NaN
# 4   NaN     NaN           NaN        NaN      NaN

# %%
###############################
# BC01 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid01, id_lineage01['superkingdom'], read_count01)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count01)*100

unclassified_count = total_count01 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)


count_superkingdom.to_csv(result_path + 'BC01_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom




###############################
# BC02 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid02, id_lineage02['superkingdom'], read_count02)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count02)*100

unclassified_count = total_count02 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)


count_superkingdom.to_csv(result_path + 'BC02_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom


###############################
# BC03 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid03, id_lineage03['superkingdom'], read_count03)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count03)*100

unclassified_count = total_count03 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)


count_superkingdom.to_csv(result_path + 'BC03_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom


###############################
# BC04 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid04, id_lineage04['superkingdom'], read_count04)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count04)*100

unclassified_count = total_count04 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_superkingdom.to_csv(result_path + 'BC04_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom


###############################
# BC05 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid05, id_lineage05['superkingdom'], read_count05)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count05)*100

unclassified_count = total_count05 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_superkingdom.to_csv(result_path + 'BC05_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom




###############################
# BC06 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid06, id_lineage06['superkingdom'], read_count06)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count06)*100

unclassified_count = total_count06 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_superkingdom.to_csv(result_path + 'BC06_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom


###############################
# BC07 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid07, id_lineage07['superkingdom'], read_count07)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count07)*100

unclassified_count = total_count07 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)


count_superkingdom.to_csv(result_path + 'BC07_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom


###############################
# BC08 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid08, id_lineage08['superkingdom'], read_count08)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count08)*100

unclassified_count = total_count08 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_superkingdom.to_csv(result_path + 'BC08_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom


###############################
# BC09 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid09, id_lineage09['superkingdom'], read_count09)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count09)*100

unclassified_count = total_count09 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_superkingdom.to_csv(result_path + 'BC09_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom




###############################
# BC10 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid10, id_lineage10['superkingdom'], read_count10)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count10)*100

unclassified_count = total_count10 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)


count_superkingdom.to_csv(result_path + 'BC10_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom


###############################
# BC11 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid11, id_lineage11['superkingdom'], read_count11)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count11)*100

unclassified_count = total_count11 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)


count_superkingdom.to_csv(result_path + 'BC11_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom


###############################
# BC012 superkingdom: Read count 

superkingdom = pd.DataFrame(list(zip(taxid12, id_lineage12['superkingdom'], read_count12)), 
                            columns=['taxid', 'superkingdom', 'read_count'] )


count_superkingdom = pd.DataFrame(superkingdom.groupby('superkingdom')['read_count'].sum())
count_superkingdom.insert(0, 'name', '')


name = []
for i in count_superkingdom.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_superkingdom['name'] = name
count_superkingdom = count_superkingdom.sort_values(by=['read_count'], ascending=False)

count_superkingdom['percentage'] = (count_superkingdom['read_count'] / total_count12)*100

unclassified_count = total_count12 - count_superkingdom.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_superkingdom.sum(axis = 0, skipna = True)[2]
count_superkingdom = count_superkingdom.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)


count_superkingdom.to_csv(result_path + 'BC12_count_superkingdom_noSelect.csv', encoding='utf-8')
count_superkingdom
# Out:
#            name  read_count  percentage
# 0      Bacteria      147803       100.0
# 1  Unclassified           0         0.0

# %%
#########################
# BC01 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid01, id_lineage01['phylum'], read_count01)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count01)*100

unclassified_count = total_count01 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC01_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC02 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid02, id_lineage02['phylum'], read_count02)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count02)*100

unclassified_count = total_count02 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC02_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC03 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid03, id_lineage03['phylum'], read_count03)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count03)*100

unclassified_count = total_count03 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC03_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC04 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid04, id_lineage04['phylum'], read_count04)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count04)*100

unclassified_count = total_count04 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC04_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum



#########################
# BC05 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid05, id_lineage05['phylum'], read_count05)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count05)*100

unclassified_count = total_count05 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC05_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC06 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid06, id_lineage06['phylum'], read_count06)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count06)*100

unclassified_count = total_count06 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC06_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC07 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid07, id_lineage07['phylum'], read_count07)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count07)*100

unclassified_count = total_count07 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC07_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC08 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid08, id_lineage08['phylum'], read_count08)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count08)*100

unclassified_count = total_count08 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC08_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC09 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid09, id_lineage09['phylum'], read_count09)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count09)*100

unclassified_count = total_count09 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC09_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC10 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid10, id_lineage10['phylum'], read_count10)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count10)*100

unclassified_count = total_count10 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC10_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC11 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid11, id_lineage11['phylum'], read_count11)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count11)*100

unclassified_count = total_count11 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC11_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum


#########################
# BC12 phylum: Read count 

phylum = pd.DataFrame(list(zip(taxid12, id_lineage12['phylum'], read_count12)), 
                            columns=['taxid', 'phylum', 'read_count'] )


count_phylum = pd.DataFrame(phylum.groupby('phylum')['read_count'].sum())
count_phylum.insert(0, 'name', '')


name = []
for i in count_phylum.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_phylum['name'] = name
count_phylum = count_phylum.sort_values(by=['read_count'], ascending=False)

count_phylum['percentage'] = (count_phylum['read_count'] / total_count12)*100

unclassified_count = total_count12 - count_phylum.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_phylum.sum(axis = 0, skipna = True)[2]
count_phylum = count_phylum.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_phylum.to_csv(result_path + 'BC12_count_phylum_noSelect.csv', encoding='utf-8')
count_phylum
# Out:
#                           name  read_count  percentage
# 0                Bacteroidetes       72409   48.990210
# 1                   Firmicutes       65905   44.589758
# 2               Proteobacteria        3748    2.535808
# 3                Cyanobacteria         382    0.258452
# 4                  Tenericutes          87    0.058862
# 5               Actinobacteria          48    0.032476
# 6              Verrucomicrobia          25    0.016914
# 7                Lentisphaerae          11    0.007442
# 8   Candidatus Melainabacteria           5    0.003383
# 9                Synergistetes           3    0.002030
# 10                    Chlorobi           1    0.000677
# 11                Spirochaetes           1    0.000677
# 12                Fusobacteria           1    0.000677
# 13                Unclassified        5177    3.502635

# %%
########################
# BC01 class: Read count 

class_ = pd.DataFrame(list(zip(taxid01, id_lineage01['class'], read_count01)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count01)*100

unclassified_count = total_count01 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC01_count_class_noSelect.csv', encoding='utf-8')
count_class



########################
# BC02 class: Read count 

class_ = pd.DataFrame(list(zip(taxid02, id_lineage02['class'], read_count02)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count02)*100

unclassified_count = total_count02 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC02_count_class_noSelect.csv', encoding='utf-8')
count_class


########################
# BC03 class: Read count 

class_ = pd.DataFrame(list(zip(taxid03, id_lineage03['class'], read_count03)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count03)*100

unclassified_count = total_count03 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC03_count_class_noSelect.csv', encoding='utf-8')
count_class


########################
# BC04 class: Read count 

class_ = pd.DataFrame(list(zip(taxid04, id_lineage04['class'], read_count04)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count04)*100

unclassified_count = total_count04 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC04_count_class_noSelect.csv', encoding='utf-8')
count_class


########################
# BC05 class: Read count 

class_ = pd.DataFrame(list(zip(taxid05, id_lineage05['class'], read_count05)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count05)*100

unclassified_count = total_count05 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC05_count_class_noSelect.csv', encoding='utf-8')
count_class



########################
# BC06 class: Read count 

class_ = pd.DataFrame(list(zip(taxid06, id_lineage06['class'], read_count06)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count06)*100

unclassified_count = total_count06 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC06_count_class_noSelect.csv', encoding='utf-8')
count_class


########################
# BC07 class: Read count 

class_ = pd.DataFrame(list(zip(taxid07, id_lineage07['class'], read_count07)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count07)*100

unclassified_count = total_count07 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC07_count_class_noSelect.csv', encoding='utf-8')
count_class


########################
# BC08 class: Read count 

class_ = pd.DataFrame(list(zip(taxid08, id_lineage08['class'], read_count08)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count08)*100

unclassified_count = total_count08 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC08_count_class_noSelect.csv', encoding='utf-8')
count_class



########################
# BC09 class: Read count 

class_ = pd.DataFrame(list(zip(taxid09, id_lineage09['class'], read_count09)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count09)*100

unclassified_count = total_count09 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC09_count_class_noSelect.csv', encoding='utf-8')
count_class



########################
# BC10 class: Read count 

class_ = pd.DataFrame(list(zip(taxid10, id_lineage10['class'], read_count10)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count10)*100

unclassified_count = total_count10 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC10_count_class_noSelect.csv', encoding='utf-8')
count_class


########################
# BC11 class: Read count 

class_ = pd.DataFrame(list(zip(taxid11, id_lineage11['class'], read_count11)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count11)*100

unclassified_count = total_count11 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC11_count_class_noSelect.csv', encoding='utf-8')
count_class


########################
# BC12 class: Read count 

class_ = pd.DataFrame(list(zip(taxid12, id_lineage12['class'], read_count12)), 
                            columns=['taxid', 'class', 'read_count'] )


count_class = pd.DataFrame(class_.groupby('class')['read_count'].sum())
count_class.insert(0, 'name', '')


name = []
for i in count_class.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_class['name'] = name
count_class = count_class.sort_values(by=['read_count'], ascending=False)

count_class['percentage'] = (count_class['read_count'] / total_count12)*100

unclassified_count = total_count12 - count_class.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_class.sum(axis = 0, skipna = True)[2]
count_class = count_class.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_class.to_csv(result_path + 'BC12_count_class_noSelect.csv', encoding='utf-8')
count_class
# Out:
#                      name  read_count  percentage
# 0             Bacteroidia       72382   48.971942
# 1              Clostridia       52202   35.318634
# 2           Negativicutes        8575    5.801641
# 3     Gammaproteobacteria        1468    0.993214
# 4      Betaproteobacteria        1424    0.963445
# 5     Alphaproteobacteria         506    0.342348
# 6        Erysipelotrichia         347    0.234772
# 7                 Bacilli         320    0.216504
# 8     Deltaproteobacteria         297    0.200943
# 9              Mollicutes          87    0.058862
# 10       Verrucomicrobiae          25    0.016914
# 11         Actinobacteria          23    0.015561
# 12           Tissierellia          18    0.012178
# 13         Coriobacteriia          16    0.010825
# 14          Lentisphaeria           9    0.006089
# 15            Synergistia           3    0.002030
# 16         Acidimicrobiia           3    0.002030
# 17         Flavobacteriia           2    0.001353
# 18          Fusobacteriia           1    0.000677
# 19           Spirochaetia           1    0.000677
# 20              Chlorobia           1    0.000677
# 21  Epsilonproteobacteria           1    0.000677
# 22           Unclassified       10092    6.828008

# %%
########################
# BC01 order: Read count 

order = pd.DataFrame(list(zip(taxid01, id_lineage01['order'], read_count01)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count01)*100

unclassified_count = total_count01 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC01_count_order_noSelect.csv', encoding='utf-8')
count_order



########################
# BC02 order: Read count 

order = pd.DataFrame(list(zip(taxid02, id_lineage02['order'], read_count02)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count02)*100

unclassified_count = total_count02 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC02_count_order_noSelect.csv', encoding='utf-8')
count_order


########################
# BC03 order: Read count 

order = pd.DataFrame(list(zip(taxid03, id_lineage03['order'], read_count03)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count03)*100

unclassified_count = total_count03 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC03_count_order_noSelect.csv', encoding='utf-8')
count_order


########################
# BC04 order: Read count 

order = pd.DataFrame(list(zip(taxid04, id_lineage04['order'], read_count04)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count04)*100

unclassified_count = total_count04 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC04_count_order_noSelect.csv', encoding='utf-8')
count_order


########################
# BC05 order: Read count 

order = pd.DataFrame(list(zip(taxid05, id_lineage05['order'], read_count05)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count05)*100

unclassified_count = total_count05 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC05_count_order_noSelect.csv', encoding='utf-8')
count_order



########################
# BC06 order: Read count 

order = pd.DataFrame(list(zip(taxid06, id_lineage06['order'], read_count06)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count06)*100

unclassified_count = total_count06 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC06_count_order_noSelect.csv', encoding='utf-8')
count_order


########################
# BC07 order: Read count 

order = pd.DataFrame(list(zip(taxid07, id_lineage07['order'], read_count07)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count07)*100

unclassified_count = total_count07 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC07_count_order_noSelect.csv', encoding='utf-8')
count_order


########################
# BC08 order: Read count 

order = pd.DataFrame(list(zip(taxid08, id_lineage08['order'], read_count08)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count08)*100

unclassified_count = total_count08 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC08_count_order_noSelect.csv', encoding='utf-8')
count_order



########################
# BC09 order: Read count 

order = pd.DataFrame(list(zip(taxid09, id_lineage09['order'], read_count09)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count09)*100

unclassified_count = total_count09 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC09_count_order_noSelect.csv', encoding='utf-8')
count_order



########################
# BC10 order: Read count 

order = pd.DataFrame(list(zip(taxid10, id_lineage10['order'], read_count10)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count10)*100

unclassified_count = total_count10 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC10_count_order_noSelect.csv', encoding='utf-8')
count_order


########################
# BC11 order: Read count 

order = pd.DataFrame(list(zip(taxid11, id_lineage11['order'], read_count11)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count11)*100

unclassified_count = total_count11 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC11_count_order_noSelect.csv', encoding='utf-8')
count_order


########################
# BC12 order: Read count 

order = pd.DataFrame(list(zip(taxid12, id_lineage12['order'], read_count12)), 
                            columns=['taxid', 'order', 'read_count'] )


count_order = pd.DataFrame(order.groupby('order')['read_count'].sum())
count_order.insert(0, 'name', '')

name = []
for i in count_order.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_order['name'] = name
count_order = count_order.sort_values(by=['read_count'], ascending=False)

count_order['percentage'] = (count_order['read_count'] / total_count12)*100

unclassified_count = total_count12 - count_order.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_order.sum(axis = 0, skipna = True)[2]
count_order = count_order.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_order.to_csv(result_path + 'BC12_count_order_noSelect.csv', encoding='utf-8')
count_order
# Out:
#                       name  read_count  percentage
# 0            Bacteroidales       72358   48.955705
# 1            Clostridiales       52168   35.295630
# 2        Acidaminococcales        3809    2.577079
# 3          Selenomonadales        2145    1.451256
# 4          Burkholderiales        1406    0.951266
# 5         Enterobacterales        1309    0.885638
# 6       Erysipelotrichales         347    0.234772
# 7       Desulfovibrionales         265    0.179293
# 8          Lactobacillales         229    0.154936
# 9          Caulobacterales         135    0.091338
# 10          Pasteurellales         117    0.079159
# 11         Oscillatoriales          82    0.055479
# 12              Bacillales          72    0.048713
# 13          Veillonellales          71    0.048037
# 14             Rhizobiales          41    0.027740
# 15         Mycoplasmatales          40    0.027063
# 16       Entomoplasmatales          33    0.022327
# 17        Rhodospirillales          32    0.021650
# 18           Kiloniellales          29    0.019621
# 19      Verrucomicrobiales          25    0.016914
# 20            Myxococcales          25    0.016914
# 21         Rhodobacterales          24    0.016238
# 22              Nostocales          19    0.012855
# 23          Tissierellales          16    0.010825
# 24        Coriobacteriales          14    0.009472
# 25        Sphingomonadales           6    0.004059
# 26       Micromonosporales           6    0.004059
# 27         Synechococcales           6    0.004059
# 28         Kordiimonadales           5    0.003383
# 29      Vampirovibrionales           5    0.003383
# 30      Desulfuromonadales           5    0.003383
# 31         Pseudomonadales           4    0.002706
# 32        Streptomycetales           4    0.002706
# 33             Vibrionales           3    0.002030
# 34        Acidimicrobiales           3    0.002030
# 35           Synergistales           3    0.002030
# 36       Oceanospirillales           2    0.001353
# 37          Eggerthellales           2    0.001353
# 38        Flavobacteriales           2    0.001353
# 39        Marinilabiliales           2    0.001353
# 40         Xanthomonadales           2    0.001353
# 41            Chromatiales           2    0.001353
# 42     Propionibacteriales           1    0.000677
# 43                 Orbales           1    0.000677
# 44           Rickettsiales           1    0.000677
# 45           Micrococcales           1    0.000677
# 46         Alteromonadales           1    0.000677
# 47  Thermoanaerobacterales           1    0.000677
# 48          Kineosporiales           1    0.000677
# 49          Spirochaetales           1    0.000677
# 50          Sneathiellales           1    0.000677
# 51           Aeromonadales           1    0.000677
# 52       Campylobacterales           1    0.000677
# 53         Methylococcales           1    0.000677
# 54       Acholeplasmatales           1    0.000677
# 55         Fusobacteriales           1    0.000677
# 56            Chlorobiales           1    0.000677
# 57        Natranaerobiales           1    0.000677
# 58            Unclassified       12914    8.737306

# %%
#########################
# BC01 family: Read count 

family = pd.DataFrame(list(zip(taxid01, id_lineage01['family'], read_count01)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count01)*100

unclassified_count = total_count01 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC01_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC02 family: Read count 

family = pd.DataFrame(list(zip(taxid02, id_lineage02['family'], read_count02)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count02)*100

unclassified_count = total_count02 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC02_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC03 family: Read count 

family = pd.DataFrame(list(zip(taxid03, id_lineage03['family'], read_count03)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count03)*100

unclassified_count = total_count03 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC03_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC04 family: Read count 

family = pd.DataFrame(list(zip(taxid04, id_lineage04['family'], read_count04)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count04)*100

unclassified_count = total_count04 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC04_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC05 family: Read count 

family = pd.DataFrame(list(zip(taxid05, id_lineage05['family'], read_count05)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count05)*100

unclassified_count = total_count05 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC05_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC06 family: Read count 

family = pd.DataFrame(list(zip(taxid06, id_lineage06['family'], read_count06)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:

    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count06)*100

unclassified_count = total_count06 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC06_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC07 family: Read count 

family = pd.DataFrame(list(zip(taxid07, id_lineage07['family'], read_count07)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count07)*100

unclassified_count = total_count07 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC07_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC08 family: Read count 

family = pd.DataFrame(list(zip(taxid08, id_lineage08['family'], read_count08)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count08)*100

unclassified_count = total_count08 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC08_count_family_noSelect.csv', encoding='utf-8')
count_family



#########################
# BC09 family: Read count 

family = pd.DataFrame(list(zip(taxid09, id_lineage09['family'], read_count09)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count09)*100

unclassified_count = total_count09 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC09_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC10 family: Read count 

family = pd.DataFrame(list(zip(taxid10, id_lineage10['family'], read_count10)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:

    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count10)*100

unclassified_count = total_count10 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC10_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC11 family: Read count 

family = pd.DataFrame(list(zip(taxid11, id_lineage11['family'], read_count11)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count11)*100

unclassified_count = total_count11 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC11_count_family_noSelect.csv', encoding='utf-8')
count_family


#########################
# BC12 family: Read count 

family = pd.DataFrame(list(zip(taxid12, id_lineage12['family'], read_count12)), 
                            columns=['taxid', 'family', 'read_count'] )


count_family = pd.DataFrame(family.groupby('family')['read_count'].sum())
count_family.insert(0, 'name', '')

name = []
for i in count_family.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_family['name'] = name
count_family = count_family.sort_values(by=['read_count'], ascending=False)

count_family['percentage'] = (count_family['read_count'] / total_count12)*100

unclassified_count = total_count12 - count_family.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_family.sum(axis = 0, skipna = True)[2]
count_family = count_family.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_family.to_csv(result_path + 'BC12_count_family_noSelect.csv', encoding='utf-8')
count_family
# Out:
#                                           name  read_count  percentage
# 0                               Prevotellaceae       26694   18.060527
# 1                               Tannerellaceae       20746   14.036251
# 2                              Ruminococcaceae       18992   12.849536
# 3                               Bacteroidaceae       17693   11.970664
# 4                              Lachnospiraceae       15446   10.450397
# 5                           Acidaminococcaceae        3809    2.577079
# 6                             Oscillospiraceae        3743    2.532425
# 7                             Selenomonadaceae        2009    1.359242
# 8                                Rikenellaceae        1995    1.349770
# 9                       Hungateiclostridiaceae        1254    0.848427
# 10                          Enterobacteriaceae        1053    0.712435
# 11                            Odoribacteraceae         915    0.619067
# 12                              Sutterellaceae         821    0.555469
# 13                         Erysipelotrichaceae         347    0.234772
# 14                         Desulfovibrionaceae         264    0.178616
# 15                            Caulobacteraceae         135    0.091338
# 16                              Clostridiaceae         124    0.083895
# 17                             Pasteurellaceae         117    0.079159
# 18                            Streptococcaceae         115    0.077806
# 19                             Barnesiellaceae          90    0.060892
# 20                             Veillonellaceae          71    0.048037
# 21                            Oxalobacteraceae          69    0.046684
# 22   Clostridiales Family XIII. Incertae Sedis          54    0.036535
# 23                       Peptostreptococcaceae          51    0.034505
# 24                          Gracilibacteraceae          47    0.031799
# 25                         Christensenellaceae          45    0.030446
# 26                               Sporomusaceae          43    0.029093
# 27                            Paenibacillaceae          41    0.027740
# 28                            Mycoplasmataceae          40    0.027063
# 29                            Lactobacillaceae          39    0.026386
# ..                                         ...         ...         ...
# 82                                Brucellaceae           1    0.000677
# 83                             Kineosporiaceae           1    0.000677
# 84                           Microbacteriaceae           1    0.000677
# 85                                    Orbaceae           1    0.000677
# 86                              Aeromonadaceae           1    0.000677
# 87                         Syntrophomonadaceae           1    0.000677
# 88                            Methylococcaceae           1    0.000677
# 89                           Marinilabiliaceae           1    0.000677
# 90                             Spirochaetaceae           1    0.000677
# 91                         Alicyclobacillaceae           1    0.000677
# 92                               Aerococcaceae           1    0.000677
# 93                            Synechococcaceae           1    0.000677
# 94                                 Erwiniaceae           1    0.000677
# 95                              Morganellaceae           1    0.000677
# 96                               Chlorobiaceae           1    0.000677
# 97                     Thermoanaerobacteraceae           1    0.000677
# 98                         Verrucomicrobiaceae           1    0.000677
# 99                           Crocinitomicaceae           1    0.000677
# 100                        Desulfuromonadaceae           1    0.000677
# 101                         Acholeplasmataceae           1    0.000677
# 102                     Pseudoalteromonadaceae           1    0.000677
# 103                          Heliobacteriaceae           1    0.000677
# 104                              Archangiaceae           1    0.000677
# 105                          Natranaerobiaceae           1    0.000677
# 106                          Flavobacteriaceae           1    0.000677
# 107                            Sneathiellaceae           1    0.000677
# 108                           Proteinivoraceae           1    0.000677
# 109                         Prolixibacteraceae           1    0.000677
# 110                           Leptotrichiaceae           1    0.000677
# 111                               Unclassified       30494   20.631516
#
# [112 rows x 3 columns]

# %%
########################
# BC01 genus: Read count 

genus = pd.DataFrame(list(zip(taxid01, id_lineage01['genus'], read_count01)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count01)*100

unclassified_count = total_count01 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)


count_genus.to_csv(result_path + 'BC01_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC02 genus: Read count 

genus = pd.DataFrame(list(zip(taxid02, id_lineage02['genus'], read_count02)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count02)*100

unclassified_count = total_count02 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC02_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC03 genus: Read count 

genus = pd.DataFrame(list(zip(taxid03, id_lineage03['genus'], read_count03)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count03)*100

unclassified_count = total_count03 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC03_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC04 genus: Read count 

genus = pd.DataFrame(list(zip(taxid04, id_lineage04['genus'], read_count04)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count04)*100

unclassified_count = total_count04 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC04_count_genus_noSelect.csv', encoding='utf-8')
count_genus



########################
# BC05 genus: Read count 

genus = pd.DataFrame(list(zip(taxid05, id_lineage05['genus'], read_count05)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count05)*100

unclassified_count = total_count05 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC05_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC06 genus: Read count 

genus = pd.DataFrame(list(zip(taxid06, id_lineage06['genus'], read_count06)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count06)*100

unclassified_count = total_count06 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC06_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC07 genus: Read count 

genus = pd.DataFrame(list(zip(taxid07, id_lineage07['genus'], read_count07)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count07)*100

unclassified_count = total_count07 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC07_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC08 genus: Read count 

genus = pd.DataFrame(list(zip(taxid08, id_lineage08['genus'], read_count08)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count08)*100

unclassified_count = total_count08 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC08_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC09 genus: Read count 

genus = pd.DataFrame(list(zip(taxid09, id_lineage09['genus'], read_count09)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count09)*100

unclassified_count = total_count09 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC09_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC10 genus: Read count 

genus = pd.DataFrame(list(zip(taxid10, id_lineage10['genus'], read_count10)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count10)*100

unclassified_count = total_count10 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC10_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC11 genus: Read count 

genus = pd.DataFrame(list(zip(taxid11, id_lineage11['genus'], read_count11)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count11)*100

unclassified_count = total_count11 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC11_count_genus_noSelect.csv', encoding='utf-8')
count_genus


########################
# BC12 genus: Read count 

genus = pd.DataFrame(list(zip(taxid12, id_lineage12['genus'], read_count12)), 
                            columns=['taxid', 'genus', 'read_count'] )


count_genus = pd.DataFrame(genus.groupby('genus')['read_count'].sum())
count_genus.insert(0, 'name', '')

name = []
for i in count_genus.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_genus['name'] = name
count_genus = count_genus.sort_values(by=['read_count'], ascending=False)

count_genus['percentage'] = (count_genus['read_count'] / total_count12)*100

unclassified_count = total_count12 - count_genus.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_genus.sum(axis = 0, skipna = True)[2]
count_genus = count_genus.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_genus.to_csv(result_path + 'BC12_count_genus_noSelect.csv', encoding='utf-8')
count_genus
# Out:
#                     name  read_count  percentage
# 0             Prevotella       25886   17.513853
# 1        Parabacteroides       20456   13.840044
# 2            Bacteroides       17567   11.885415
# 3      Lachnoclostridium        4092    2.768550
# 4          Oscillibacter        3743    2.532425
# 5           Ruminococcus        2058    1.392394
# 6              Alistipes        1993    1.348416
# 7              Megamonas        1662    1.124470
# 8              Roseburia        1346    0.910672
# 9                Blautia        1026    0.694167
# 10            Klebsiella         625    0.422860
# 11          Anaerotignum         582    0.393767
# 12           Odoribacter         563    0.380912
# 13            Kineothrix         395    0.267248
# 14         Butyricimonas         343    0.232066
# 15        Paraprevotella         294    0.198913
# 16   Hungateiclostridium         257    0.173880
# 17         Desulfovibrio         249    0.168467
# 18     Ruminiclostridium         194    0.131256
# 19          Anaerostipes         150    0.101486
# 20         Brevundimonas         131    0.088631
# 21         Faecalicatena         124    0.083895
# 22           Citrobacter         116    0.078483
# 23           Haemophilus          91    0.061568
# 24           Barnesiella          90    0.060892
# 25           Clostridium          61    0.041271
# 26         Streptococcus          57    0.038565
# 27           Lactococcus          53    0.035859
# 28         Gracilibacter          47    0.031799
# 29       Christensenella          45    0.030446
# ..                   ...         ...         ...
# 151         Photorhabdus           1    0.000677
# 152          Brasilonema           1    0.000677
# 153    Halolactibacillus           1    0.000677
# 154   Desulfitobacterium           1    0.000677
# 155         Burkholderia           1    0.000677
# 156        Salimicrobium           1    0.000677
# 157     Desulfotomaculum           1    0.000677
# 158           Rhodovulum           1    0.000677
# 159        Neorickettsia           1    0.000677
# 160         Azospirillum           1    0.000677
# 161            Geobacter           1    0.000677
# 162     Carboxydothermus           1    0.000677
# 163             Hirschia           1    0.000677
# 164      Desulfofundulus           1    0.000677
# 165              Erwinia           1    0.000677
# 166        Brevibacillus           1    0.000677
# 167          Anaerospora           1    0.000677
# 168           Maribacter           1    0.000677
# 169    Pseudoalteromonas           1    0.000677
# 170          Planococcus           1    0.000677
# 171         Ochrobactrum           1    0.000677
# 172          Sneathiella           1    0.000677
# 173          Kineosporia           1    0.000677
# 174    Ornithinibacillus           1    0.000677
# 175      Marinobacterium           1    0.000677
# 176         Oribacterium           1    0.000677
# 177        Acinetobacter           1    0.000677
# 178             Bacillus           1    0.000677
# 179          Desulfallas           1    0.000677
# 180         Unclassified       62743   42.450424
#
# [181 rows x 3 columns]

# %%
##########################
# BC01 species: Read count 

species = pd.DataFrame(list(zip(taxid01, id_lineage01['species'], read_count01)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count01)*100

unclassified_count = total_count01 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC01_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC02 species: Read count 

species = pd.DataFrame(list(zip(taxid02, id_lineage02['species'], read_count02)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count02)*100

unclassified_count = total_count02 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC02_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC03 species: Read count 

species = pd.DataFrame(list(zip(taxid03, id_lineage03['species'], read_count03)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count03)*100

unclassified_count = total_count03 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC03_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC04 species: Read count 

species = pd.DataFrame(list(zip(taxid04, id_lineage04['species'], read_count04)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count04)*100

unclassified_count = total_count04 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC04_count_species_noSelect.csv', encoding='utf-8')
count_species



##########################
# BC05 species: Read count 

species = pd.DataFrame(list(zip(taxid05, id_lineage05['species'], read_count05)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count05)*100

unclassified_count = total_count05 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC05_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC06 species: Read count 

species = pd.DataFrame(list(zip(taxid06, id_lineage06['species'], read_count06)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count06)*100

unclassified_count = total_count06 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC06_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC07 species: Read count 

species = pd.DataFrame(list(zip(taxid07, id_lineage07['species'], read_count07)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count07)*100

unclassified_count = total_count07 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC07_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC08 species: Read count 

species = pd.DataFrame(list(zip(taxid08, id_lineage08['species'], read_count08)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count08)*100

unclassified_count = total_count08 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC08_count_species_noSelect.csv', encoding='utf-8')
count_species



##########################
# BC09 species: Read count 

species = pd.DataFrame(list(zip(taxid09, id_lineage09['species'], read_count09)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count09)*100

unclassified_count = total_count09 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC09_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC10 species: Read count 

species = pd.DataFrame(list(zip(taxid10, id_lineage10['species'], read_count10)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count10)*100

unclassified_count = total_count10 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC10_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC11 species: Read count 

species = pd.DataFrame(list(zip(taxid11, id_lineage11['species'], read_count11)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count11)*100

unclassified_count = total_count11 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC11_count_species_noSelect.csv', encoding='utf-8')
count_species


##########################
# BC12 species: Read count 

species = pd.DataFrame(list(zip(taxid12, id_lineage12['species'], read_count12)), 
                            columns=['taxid', 'species', 'read_count'] )


count_species = pd.DataFrame(species.groupby('species')['read_count'].sum())
count_species.insert(0, 'name', '')

name = []
for i in count_species.index.values:
    
    name.append(list(ncbi.get_taxid_translator([i]).values())[0])
    
    
count_species['name'] = name
count_species = count_species.sort_values(by=['read_count'], ascending=False)

count_species['percentage'] = (count_species['read_count'] / total_count12)*100

unclassified_count = total_count12 - count_species.sum(axis = 0, skipna = True)[1]
unclassified_per = 100 - count_species.sum(axis = 0, skipna = True)[2]
count_species = count_species.append({"name": "Unclassified", "read_count": unclassified_count,"percentage":unclassified_per}, ignore_index=True)

count_species.to_csv(result_path + 'BC12_count_species_noSelect.csv', encoding='utf-8')
count_species
# Out:
#                                name  read_count  percentage
# 0                  Prevotella copri       25418   17.197215
# 1        Parabacteroides distasonis       16104   10.895584
# 2              Bacteroides plebeius        6189    4.187330
# 3             Bacteroides coprocola        5497    3.719140
# 4            Parabacteroides merdae        3767    2.548663
# 5       Oscillibacter valericigenes        3031    2.050703
# 6                Ruminococcus albus        1916    1.296320
# 7              Bacteroides vulgatus        1682    1.138001
# 8             [Clostridium] bolteae        1356    0.917437
# 9              Alistipes putredinis        1318    0.891728
# 10            Megamonas rupellensis        1013    0.685372
# 11         Bacteroides massiliensis         959    0.648837
# 12               Bacteroides caccae         738    0.499313
# 13        Oscillibacter ruminantium         712    0.481722
# 14             Megamonas funiformis         601    0.406622
# 15            Bacteroides uniformis         590    0.399180
# 16         Odoribacter splanchnicus         563    0.380912
# 17    [Desulfotomaculum] guttoideum         547    0.370087
# 18                 Roseburia faecis         543    0.367381
# 19   Anaerotignum lactatifermentans         542    0.366704
# 20            Klebsiella pneumoniae         541    0.366028
# 21      Parabacteroides goldsteinii         506    0.342348
# 22                 Alistipes shahii         430    0.290928
# 23            [Clostridium] indolis         422    0.285515
# 24             Kineothrix alysoides         395    0.267248
# 25                Roseburia hominis         337    0.228006
# 26    [Clostridium] saccharolyticum         294    0.198913
# 27             Paraprevotella clara         293    0.198237
# 28       Lachnoclostridium pacaense         291    0.196884
# 29          Roseburia inulinivorans         272    0.184029
# ..                              ...         ...         ...
# 496               Coprococcus comes           1    0.000677
# 497      Paenibacillus provencensis           1    0.000677
# 498                Prevotella amnii           1    0.000677
# 499         Anaerobranca horikoshii           1    0.000677
# 500            Gilliamella mensalis           1    0.000677
# 501         Bhargavaea beijingensis           1    0.000677
# 502           Macrococcus bohemicus           1    0.000677
# 503          Tissierella creatinini           1    0.000677
# 504               Prevotella micans           1    0.000677
# 505          Paenibacillus graminis           1    0.000677
# 506           Propionispira arcuata           1    0.000677
# 507        Nocardioides islandensis           1    0.000677
# 508           Brasilonema terrestre           1    0.000677
# 509               Prevotella oryzae           1    0.000677
# 510       Marinobacterium aestuarii           1    0.000677
# 511             Acutalibacter muris           1    0.000677
# 512      Paraprevotella xylaniphila           1    0.000677
# 513      Lactobacillus coleohominis           1    0.000677
# 514           Maritalea myrionectae           1    0.000677
# 515         Sutterella massiliensis           1    0.000677
# 516         Granulicatella adiacens           1    0.000677
# 517   Phaeospirillum chandramohanii           1    0.000677
# 518      Pectobacterium brasiliense           1    0.000677
# 519        Atopostipes suicloacalis           1    0.000677
# 520           Delftia tsuruhatensis           1    0.000677
# 521   Lachnoanaerobaculum saburreum           1    0.000677
# 522            Clostridium chauvoei           1    0.000677
# 523    Herbaspirillum autotrophicum           1    0.000677
# 524      Raoultella ornithinolytica           1    0.000677
# 525                    Unclassified       62742   42.449747
#
# [526 rows x 3 columns]
